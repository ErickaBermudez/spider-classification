# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt

models = tf.keras.models
layers = tf.keras.layers
utils = tf.keras.utils
losses = tf.keras.losses
optimizers = tf.keras.optimizers 
metrics = tf.keras.metrics
preprocessing_image = tf.keras.preprocessing.image
applications = tf.keras.applications

# %% [markdown]
# ### Convolution Block

# %%
def conv_block(x, filters, block_num, conv_num, strides=(1,1)):
    name = 'block{}_conv{}_'.format(block_num, conv_num)

    # conv-BN-relu
    x = layers.Conv2D(filters, (3,3), strides=(2,2), use_bias=False, name=name)(x)
    x = layers.BatchNormalization(name=name+'bn')(x)
    x = layers.Activation('relu', name=name+'act')(x)

    return x

# %% [markdown]
# ### Separable Convolution Block

# %%
def separable_conv_block(x, filters, block_num, conv_num, pre_activation=None):
    name = 'block{}_sepconv{}_'.format(block_num, conv_num)

    if pre_activation is True:
        x = layers.Activation('relu', name=name+'act')(x)

    # (relu)-sepconv-BN-(relu)
    x = layers.SeparableConv2D(filters, (3,3), padding='same', use_bias=False, name=name)(x)
    x = layers.BatchNormalization(name=name+'bn')(x)

    if pre_activation is False:
        x = layers.Activation('relu', name=name+'act')(x)


    return x

# %% [markdown]
# ### Middle Flow Block

# %%
def middle_flow_block(x, filters, block_num):

    # middle flow

    residual = x

    x = separable_conv_block(x, filters, block_num=block_num, conv_num='1', pre_activation=True)
    x = separable_conv_block(x, filters, block_num=block_num, conv_num='2', pre_activation=True)
    x = separable_conv_block(x, filters, block_num=block_num, conv_num='3', pre_activation=True)

    return layers.add([x, residual])

# %% [markdown]
# ### Exception Block

# %%
def xception_block(x, filters, block_num, pre_activation=True):
    block = 'block{}_'.format(block_num)
    filter_conv1, filter_conv2 = filters

    # residual conv branch
    residual = layers.Conv2D(filter_conv2, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
    residual = layers.BatchNormalization()(residual)

    # separable conv block
    x = separable_conv_block(x, filter_conv1, block_num=block_num, conv_num='1', pre_activation=pre_activation)
    x = separable_conv_block(x, filter_conv2, block_num=block_num, conv_num='2', pre_activation=True)

    # downsampling and merging
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same', name=block+'pool')(x)

    return layers.add([x, residual])

# %% [markdown]
# ### Xception Model

# %%
def Xception(input_shape=(299,299,3), classes=1000):
    """Instantiates the Xception architecture.
    """

    img_input = layers.Input(shape=input_shape)

    #===========ENTRY FLOW==============
    #Block 1
    x = conv_block(img_input, 32, block_num='1', conv_num='1', strides=(2,2))
    x = conv_block(x, 64, block_num='1', conv_num='2')

    #Block 2
    x = xception_block(x, (128, 128), '2', pre_activation=False)

    #Block 3
    x = xception_block(x, (256, 256), '3')

    #Block 4
    x = xception_block(x, (728, 728), '4')


    #===========MIDDLE FLOW===============
    for i in range(8):
        block_num = str(5+i)
        x = middle_flow_block(x, 728, block_num)

    #========EXIT FLOW============
    #Block 13
    x = xception_block(x, (728, 1024), '13') # second conv is different

    # Block 14
    x = separable_conv_block(x, 1536, block_num='14', conv_num='1', pre_activation=False)
    x = separable_conv_block(x, 2048, block_num='14', conv_num='2', pre_activation=False)

    # logistic regression
    x = layers.GlobalAveragePooling2D(name='avg_pool')(x)
    x = layers.Dense(classes, activation='softmax', name='predictions')(x)

    # Create model.
    model = models.Model(inputs=img_input, outputs=x, name='xception')
    return model

# %%
xception = Xception()
xception.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  block1_conv1_ (Conv2D)         (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 149, 149, 32  128        ['block1_conv1_[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 149, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2_ (Conv2D)         (None, 74, 74, 64)   18432       ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNormaliz  (None, 74, 74, 64)  256         ['block1_conv2_[0][0]']
#  ation)
#
#  block1_conv2_act (Activation)  (None, 74, 74, 64)   0           ['block1_conv2_bn[0][0]']
#
#  block2_sepconv1_ (SeparableCon  (None, 74, 74, 128)  8768       ['block1_conv2_act[0][0]']
#  v2D)
#
#  block2_sepconv1_bn (BatchNorma  (None, 74, 74, 128)  512        ['block2_sepconv1_[0][0]']
#  lization)
#
#  block2_sepconv1_act (Activatio  (None, 74, 74, 128)  0          ['block2_sepconv1_bn[0][0]']
#  n)
#
#  block2_sepconv2_act (Activatio  (None, 74, 74, 128)  0          ['block2_sepconv1_act[0][0]']
#  n)
#
#  block2_sepconv2_ (SeparableCon  (None, 74, 74, 128)  17536      ['block2_sepconv2_act[0][0]']
#  v2D)
#
#  block2_sepconv2_bn (BatchNorma  (None, 74, 74, 128)  512        ['block2_sepconv2_[0][0]']
#  lization)
#
#  conv2d (Conv2D)                (None, 37, 37, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 37, 37, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 37, 37, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 37, 37, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 37, 37, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1_ (SeparableCon  (None, 37, 37, 256)  33920      ['block3_sepconv1_act[0][0]']
#  v2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 37, 37, 256)  1024       ['block3_sepconv1_[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 37, 37, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2_ (SeparableCon  (None, 37, 37, 256)  67840      ['block3_sepconv2_act[0][0]']
#  v2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 37, 37, 256)  1024       ['block3_sepconv2_[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 19, 19, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 19, 19, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 19, 19, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 19, 19, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1_ (SeparableCon  (None, 19, 19, 728)  188672     ['block4_sepconv1_act[0][0]']
#  v2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block4_sepconv1_[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2_ (SeparableCon  (None, 19, 19, 728)  536536     ['block4_sepconv2_act[0][0]']
#  v2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block4_sepconv2_[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 10, 10, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 10, 10, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 10, 10, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 10, 10, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 10, 10, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1_ (SeparableCon  (None, 10, 10, 728)  536536     ['block5_sepconv1_act[0][0]']
#  v2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block5_sepconv1_[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 10, 10, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2_ (SeparableCon  (None, 10, 10, 728)  536536     ['block5_sepconv2_act[0][0]']
#  v2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block5_sepconv2_[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 10, 10, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3_ (SeparableCon  (None, 10, 10, 728)  536536     ['block5_sepconv3_act[0][0]']
#  v2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block5_sepconv3_[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 10, 10, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 10, 10, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1_ (SeparableCon  (None, 10, 10, 728)  536536     ['block6_sepconv1_act[0][0]']
#  v2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block6_sepconv1_[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 10, 10, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2_ (SeparableCon  (None, 10, 10, 728)  536536     ['block6_sepconv2_act[0][0]']
#  v2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block6_sepconv2_[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 10, 10, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3_ (SeparableCon  (None, 10, 10, 728)  536536     ['block6_sepconv3_act[0][0]']
#  v2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block6_sepconv3_[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 10, 10, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 10, 10, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1_ (SeparableCon  (None, 10, 10, 728)  536536     ['block7_sepconv1_act[0][0]']
#  v2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block7_sepconv1_[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 10, 10, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2_ (SeparableCon  (None, 10, 10, 728)  536536     ['block7_sepconv2_act[0][0]']
#  v2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block7_sepconv2_[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 10, 10, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3_ (SeparableCon  (None, 10, 10, 728)  536536     ['block7_sepconv3_act[0][0]']
#  v2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block7_sepconv3_[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 10, 10, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 10, 10, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1_ (SeparableCon  (None, 10, 10, 728)  536536     ['block8_sepconv1_act[0][0]']
#  v2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block8_sepconv1_[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 10, 10, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2_ (SeparableCon  (None, 10, 10, 728)  536536     ['block8_sepconv2_act[0][0]']
#  v2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block8_sepconv2_[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 10, 10, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3_ (SeparableCon  (None, 10, 10, 728)  536536     ['block8_sepconv3_act[0][0]']
#  v2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block8_sepconv3_[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 10, 10, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 10, 10, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1_ (SeparableCon  (None, 10, 10, 728)  536536     ['block9_sepconv1_act[0][0]']
#  v2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block9_sepconv1_[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 10, 10, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2_ (SeparableCon  (None, 10, 10, 728)  536536     ['block9_sepconv2_act[0][0]']
#  v2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block9_sepconv2_[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 10, 10, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3_ (SeparableCon  (None, 10, 10, 728)  536536     ['block9_sepconv3_act[0][0]']
#  v2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 10, 10, 728)  2912       ['block9_sepconv3_[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 10, 10, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 10, 10, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1_ (SeparableCo  (None, 10, 10, 728)  536536     ['block10_sepconv1_act[0][0]']
#  nv2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block10_sepconv1_[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 10, 10, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2_ (SeparableCo  (None, 10, 10, 728)  536536     ['block10_sepconv2_act[0][0]']
#  nv2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block10_sepconv2_[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 10, 10, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3_ (SeparableCo  (None, 10, 10, 728)  536536     ['block10_sepconv3_act[0][0]']
#  nv2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block10_sepconv3_[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 10, 10, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 10, 10, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1_ (SeparableCo  (None, 10, 10, 728)  536536     ['block11_sepconv1_act[0][0]']
#  nv2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block11_sepconv1_[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 10, 10, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2_ (SeparableCo  (None, 10, 10, 728)  536536     ['block11_sepconv2_act[0][0]']
#  nv2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block11_sepconv2_[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 10, 10, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3_ (SeparableCo  (None, 10, 10, 728)  536536     ['block11_sepconv3_act[0][0]']
#  nv2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block11_sepconv3_[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 10, 10, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 10, 10, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1_ (SeparableCo  (None, 10, 10, 728)  536536     ['block12_sepconv1_act[0][0]']
#  nv2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block12_sepconv1_[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 10, 10, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2_ (SeparableCo  (None, 10, 10, 728)  536536     ['block12_sepconv2_act[0][0]']
#  nv2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block12_sepconv2_[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 10, 10, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3_ (SeparableCo  (None, 10, 10, 728)  536536     ['block12_sepconv3_act[0][0]']
#  nv2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block12_sepconv3_[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 10, 10, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 10, 10, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1_ (SeparableCo  (None, 10, 10, 728)  536536     ['block13_sepconv1_act[0][0]']
#  nv2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 10, 10, 728)  2912       ['block13_sepconv1_[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 10, 10, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2_ (SeparableCo  (None, 10, 10, 1024  752024     ['block13_sepconv2_act[0][0]']
#  nv2D)                          )
#
#  block13_sepconv2_bn (BatchNorm  (None, 10, 10, 1024  4096       ['block13_sepconv2_[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 5, 5, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 5, 5, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 5, 5, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 5, 5, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1_ (SeparableCo  (None, 5, 5, 1536)  1582080     ['add_11[0][0]']
#  nv2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 5, 5, 1536)  6144        ['block14_sepconv1_[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 5, 5, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2_ (SeparableCo  (None, 5, 5, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  nv2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 5, 5, 2048)  8192        ['block14_sepconv2_[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 5, 5, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 22,910,480
# Trainable params: 22,855,952
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training and Evaluating

# %%
# load pre-trained Xception model and exclude top dense layer
base_model = applications.Xception(include_top=False,
                                   weights='imagenet',
                                   input_shape=(299,299,3),
                                   pooling='avg')

# %%
print("Model input shape: {}\n".format(base_model.input_shape))
print("Model output shape: {}\n".format(base_model.output_shape))
print("Model number of layers: {}\n".format(len(base_model.layers)))
# Out:
# Model input shape: (None, 299, 299, 3)
#
# Model output shape: (None, 2048)
#
# Model number of layers: 133

# %%
def fine_tune_Xception(base_model):

    # output of convolutional layers
    x = base_model.output

    # final Dense layer
    outputs = layers.Dense(15, activation='softmax')(x)

    # define model with base_model's input
    model = models.Model(inputs=base_model.input, outputs=outputs)

    # freeze weights of early layers
    # to ease training
    for layer in model.layers[:40]:
        layer.trainable = False

    return model

# %%
def compile_model(model):

    # loss
    loss = losses.categorical_crossentropy

    # optimizer
    optimizer = optimizers.RMSprop(learning_rate=0.0001)

    # metrics
    metric = [metrics.categorical_accuracy]

    # compile model with loss, optimizer, and evaluation metrics
    model.compile(optimizer, loss, metric)

    return model

# %%
model = fine_tune_Xception(base_model)
model = compile_model(model)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 149, 149, 32  864         ['input_2[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 149, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 149, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 147, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 147, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 147, 147, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 147, 147, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 147, 147, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 147, 147, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_4 (Conv2D)              (None, 74, 74, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 74, 74, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 74, 74, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  add_12 (Add)                   (None, 74, 74, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 74, 74, 128)  0          ['add_12[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 74, 74, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 74, 74, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 74, 74, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_5 (Conv2D)              (None, 37, 37, 256)  32768       ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 37, 37, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 37, 37, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  add_13 (Add)                   (None, 37, 37, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_5[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 37, 37, 256)  0          ['add_13[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 37, 37, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 37, 37, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 37, 37, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 728)  186368      ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 19, 19, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 19, 19, 728)  2912       ['conv2d_6[0][0]']
#  rmalization)
#
#  add_14 (Add)                   (None, 19, 19, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_14[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_15 (Add)                   (None, 19, 19, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_14[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_15[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_16 (Add)                   (None, 19, 19, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_15[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_16[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_17 (Add)                   (None, 19, 19, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_16[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_17[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_18 (Add)                   (None, 19, 19, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_17[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_18[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_19 (Add)                   (None, 19, 19, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_18[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_19[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_20 (Add)                   (None, 19, 19, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_19[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_20[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_21 (Add)                   (None, 19, 19, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_20[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_21[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_22 (Add)                   (None, 19, 19, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_21[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_22[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 19, 19, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 19, 19, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_7 (Conv2D)              (None, 10, 10, 1024  745472      ['add_22[0][0]']
#                                 )
#
#  block13_pool (MaxPooling2D)    (None, 10, 10, 1024  0           ['block13_sepconv2_bn[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 10, 10, 1024  4096       ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  add_23 (Add)                   (None, 10, 10, 1024  0           ['block13_pool[0][0]',
#                                 )                                 'batch_normalization_7[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 10, 10, 1536  1582080    ['add_23[0][0]']
#  v2D)                           )
#
#  block14_sepconv1_bn (BatchNorm  (None, 10, 10, 1536  6144       ['block14_sepconv1[0][0]']
#  alization)                     )
#
#  block14_sepconv1_act (Activati  (None, 10, 10, 1536  0          ['block14_sepconv1_bn[0][0]']
#  on)                            )
#
#  block14_sepconv2 (SeparableCon  (None, 10, 10, 2048  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)                           )
#
#  block14_sepconv2_bn (BatchNorm  (None, 10, 10, 2048  8192       ['block14_sepconv2[0][0]']
#  alization)                     )
#
#  block14_sepconv2_act (Activati  (None, 10, 10, 2048  0          ['block14_sepconv2_bn[0][0]']
#  on)                            )
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 15)           30735       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 20,892,215
# Trainable params: 19,192,935
# Non-trainable params: 1,699,280
# __________________________________________________________________________________________________

# %%
def preprocess_image(x):
    x /= 255.
    x -= 0.5
    x *= 2.

    # 'RGB'->'BGR'
    x = x[..., ::-1]
    # Zero-center by mean pixel
    x[..., 0] -= 103.939
    x[..., 1] -= 116.779
    x[..., 2] -= 123.68
    return x


train_datagen = preprocessing_image.ImageDataGenerator(
    preprocessing_function=preprocess_image,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = preprocessing_image.ImageDataGenerator(preprocessing_function=preprocess_image)

# %%
BASE_DIR = "data/"

train_generator = train_datagen.flow_from_directory(
    os.path.join(BASE_DIR, "train"),
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)

validation_generator = test_datagen.flow_from_directory(
    os.path.join(BASE_DIR, "valid"),
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical',
    shuffle=True)
# Out:
# Found 2185 images belonging to 15 classes.
# Found 75 images belonging to 15 classes.

# %%
history = model.fit(
    train_generator,
    epochs=2,
    steps_per_epoch=5,
    validation_data=validation_generator)
# Out:
# Epoch 1/2
# 5/5 [==============================] - 102s 21s/step - loss: 2.6977 - categorical_accuracy: 0.0750 - val_loss: 8.7302 - val_categorical_accuracy: 0.0667
# Epoch 2/2
# 5/5 [==============================] - 120s 25s/step - loss: 2.6871 - categorical_accuracy: 0.0812 - val_loss: 6.4874 - val_categorical_accuracy: 0.0667
